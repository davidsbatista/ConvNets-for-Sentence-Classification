# %%
import re
import os
import random
import numpy as np

from IPython.display import SVG

from collections import namedtuple

os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
random.seed(12345)

from keras.models import Sequential, Model
from keras.layers import Input, Dense, Embedding, Flatten
from keras.layers import Conv1D, MaxPooling1D
from keras.layers import concatenate
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils.np_utils import to_categorical
from keras.utils.vis_utils import model_to_dot

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load Datasets

# %% [markdown]
# ## TREC - Question Answering (multi-class)

# %%
# TREC - Question Answering
# http://cogcomp.cs.illinois.edu/Data/QA/QC/

TREC_Question = namedtuple("TREC_Question", "label question")

trec_train = set()
trec_test = set()

for filename in os.listdir("TREC/"):
    with open("TREC/"+filename,'r', encoding='latin_1') as f_input:
        for line in f_input:
            label, question = line.split(' ', 1)
            label = label.split(':')[0]
            question = TREC_Question(label, question)
            if filename=='TREC_10.label':
                trec_test.add(question)
            else:
                trec_train.add(question)

print("Train Samples: {}".format(len(trec_train)))
print("Test Samples : {}".format(len(trec_test)))
# Out:
# Train Samples: 5381
# Test Samples : 500

# %% [markdown]
# # Possible labels

# %%
{x.label for x in trec_train}
# Out:
# {'ABBR', 'DESC', 'ENTY', 'HUM', 'LOC', 'NUM'}

# %% [markdown]
# ## Stanford Sentiment Treebank - movie reviews with fine-grained labels

# %%
# Stanford Sentiment Treebank - movie reviews with fine-grained labels
# https://nlp.stanford.edu/sentiment/

ST_sentence = namedtuple("Stanford_Sentiment", "id sentence")
ST_score = namedtuple("Stanford_Sentiment", "id score")

sentences = []
scores = []
train = []
dev = []
test = []

for filename in ['datasetSentences.txt','datasetSplit.txt', 'sentiment_labels.txt']:
    with open("ST/"+filename,'r') as f_input:
        for line in f_input:
            
            # skip headers
            if line.startswith("sentence_index") or line.startswith('phrase id'):
                    continue
            
            # load sentences
            if filename=='datasetSentences.txt':                                
                sent_id, sentence = line.split('\t', 1)
                sample = ST_sentence(sent_id, sentence)
                sentences.append(sample)
            
            # load splits
            if filename=='datasetSplit.txt':
                sent_id, split = line.split(',', 1)
                split = int(split.strip())
                if split == 1:                    
                    train.append(sent_id)
                if split == 2:                                        
                    test.append(sent_id)
                if split == 3:
                    dev.append(sent_id)
            
            # sentences_id        
            if filename=='sentiment_labels.txt':                    
                sent_id, sent_score = line.split('|', 1)
                #sent_score = float(sent_score.strip())
                sample = ST_score(sent_id, float(sent_score.strip()))
                scores.append(sample)
                    
print("Total Nr. Samples: {}".format(len(sentences)))
print("Total Nr. Scores : {}".format(len(scores)))
print("Train  : {}".format(len(train)))
print("Dev    : {}".format(len(dev)))
print("Test   : {}".format(len(test)))
# Out:
# Total Nr. Samples: 11855
# Total Nr. Scores : 239232
# Train  : 8544
# Dev    : 1101
# Test   : 2210

# %%
{y.score for y in scores}
# Out:
# {0.0,
#  0.013889,
#  0.027778,
#  0.041667,
#  0.055556,
#  0.069444,
#  0.083333,
#  0.097222,
#  0.11111,
#  0.125,
#  0.13542,
#  0.13889,
#  0.14583,
#  0.15278,
#  0.16667,
#  0.17708,
#  0.18056,
#  0.19444,
#  0.19792,
#  0.20833,
#  0.21875,
#  0.22222,
#  0.23611,
#  0.23958,
#  0.24306,
#  0.25,
#  0.26042,
#  0.26389,
#  0.27083,
#  0.27778,
#  0.28125,
#  0.29167,
#  0.30208,
#  0.30556,
#  0.3125,
#  0.31944,
#  0.33333,
#  0.34375,
#  0.34722,
#  0.35417,
#  0.36111,
#  0.36458,
#  0.375,
#  0.38194,
#  0.38542,
#  0.38889,
#  0.39583,
#  0.40278,
#  0.40625,
#  0.41667,
#  0.42361,
#  0.42708,
#  0.43056,
#  0.4375,
#  0.44444,
#  0.44792,
#  0.45139,
#  0.45833,
#  0.46875,
#  0.47222,
#  0.47917,
#  0.48611,
#  0.48958,
#  0.49306,
#  0.5,
#  0.50694,
#  0.51042,
#  0.51389,
#  0.52083,
#  0.52778,
#  0.53125,
#  0.54167,
#  0.54861,
#  0.55208,
#  0.55556,
#  0.5625,
#  0.56944,
#  0.57292,
#  0.58333,
#  0.59028,
#  0.59375,
#  0.59722,
#  0.60417,
#  0.61111,
#  0.61458,
#  0.625,
#  0.63194,
#  0.63542,
#  0.63889,
#  0.64583,
#  0.65278,
#  0.65625,
#  0.66667,
#  0.67708,
#  0.68056,
#  0.6875,
#  0.69444,
#  0.69792,
#  0.70833,
#  0.71875,
#  0.72222,
#  0.72917,
#  0.73611,
#  0.73958,
#  0.74306,
#  0.75,
#  0.76042,
#  0.76389,
#  0.77083,
#  0.77778,
#  0.78125,
#  0.79167,
#  0.80208,
#  0.80556,
#  0.8125,
#  0.81944,
#  0.82292,
#  0.83333,
#  0.84375,
#  0.84722,
#  0.85417,
#  0.86111,
#  0.86458,
#  0.86806,
#  0.875,
#  0.88542,
#  0.88889,
#  0.89583,
#  0.90278,
#  0.90625,
#  0.91667,
#  0.92708,
#  0.93056,
#  0.9375,
#  0.94444,
#  0.94792,
#  0.95833,
#  0.96875,
#  0.97222,
#  0.98611,
#  0.98958,
#  1.0}

# %% [markdown]
# ## TODO: transform to classes or also use as regression problem

# %%
# (very positive, positive, neutral, negative, very negative), re-labeled by Socher et al. (2013).4

# %%
# 0 - 2.0 
# 2.0 - 4.0
# 4.0 - 6.0
# 6.0 - 8.0
# 8.0 - 10.0

# %% [markdown]
# ## Movie reviews with one sentence per review

# %%
# Movie reviews with one sentence per review.
# https://www.cs.cornell.edu/people/pabo/movie-review-data/

# fold 1: files tagged cv000 through cv099, in numerical order
# fold 2: files tagged cv100 through cv199, in numerical order
# fold 10: files tagged cv900 through cv999, in numerical order

folds = [set() for _ in range(10)]
Review = namedtuple("MovieReview", "label sentence")

for directory in ['MR/txt_sentoken/pos/','MR/txt_sentoken/neg/'] :
    for filename in os.listdir(directory) + os.listdir(directory):
        label = directory.split("/")[-2]        
        fold = int(filename.split("_")[0][2])
        with open(directory+filename,'r') as f_input:
            for line in f_input:
                sample = Review(label,line.strip())
                folds[fold].add(sample)

for i, x in enumerate(folds):
    print(i, len(x))
# Out:
# 0 6298
# 1 6138
# 2 6162
# 3 6357
# 4 6655
# 5 6589
# 6 6883
# 7 6551
# 8 6193
# 9 6586

# %%
{msg.label for fold in folds for msg in fold}
# Out:
# {'neg', 'pos'}

# %% [markdown]
# ## Customer Review

# %%
# CR: http://www.cs.uic.edu/~liub/FBS/sentiment-analysis.html

CustomerReview = namedtuple("Customer_Review", "aspects sentence")
data = []

for filename in os.listdir('CR/'):
    if filename=='Readme.txt':
        continue
    print(filename)
    with open('CR/'+filename,'r') as f_input:
        for line in f_input:
            if line.startswith("*"):
                continue
            # select only lines with an opinion over a feature of the product
            m = re.match(r'.*\[(.[0-9])\].*##.*',line)
            if m:
                sentence = line.split('##')[1].strip()
                aspects_string = line.split('##')[0]
                aspects = aspects_string.split(",")
                data.append(CustomerReview(aspects, sentence))
print(len(data))
# Out:
# Apex AD2600 Progressive-scan DVD player.txt
# Canon G3.txt
# Creative Labs Nomad Jukebox Zen Xtra 40GB.txt
# Nikon coolpix 4300.txt
# Nokia 6610.txt
# 1727

# %%
for msg in data:
    if len(msg.aspects) > 1:
        print(msg.aspects)
# Out:
# ['player[+2]', 'sound[-1]']
# ['look[+3]', 'panel button layout[+3]', 'feature[+2]']
# ['forward[+2]', ' rewind[+2]']
# ['play[+2]', ' dvd-r[+1]']
# ['remote control[-1]', ' mp3 filename[-1]']
# ['play[-2]', ' disney movie[-2]']
# ['player[+1]', ' look[+3]']
# ['customer service[-3]', ' technical support[-3]']
# ['dvd[-2]', ' read[-2]', ' play[-2]']
# ['picture quality[+2]', 'feature[+2]']
# ['look[+2]', ' feature[+2]']
# ['play[-2]', ' dvd[-2]']
# ['jpeg slideshow[+2]', 'mpeg1[+1]']
# ['picture[-2]', ' player[-3][p]']
# ['play[-2]', ' disc[-2]']
# ['play[-2]', ' dvd[-2]']
# ['picture[-2]', ' player[-2][p]']
# ['dvd[-2]', ' play[-2]']
# ['dvd[-2]', ' play[-2]']
# ['format[+2][u]', 'progressive scan[+2]']
# ['play[+2]', ' different file[+2]']
# ['play[+2]', ' mpeg[+2]']
# ['no disc[-2]', ' screen[-3][u]']
# ['player[+3]', ' format[+2]']
# ['progressive scan[+2]', 'remote[+3]']
# ['play[-2]', ' dvd[-2]', ' no disc[-2]']
# ['look[+2][u]', 'panel[+2]']
# ['dvd[-2]', ' picture[-2]', ' play[-2]']
# ['picture[-2]', ' sound[-2]']
# ['dvd[-2]', ' read[-2]', ' no disc[-2]']
# ['progressive scan player[+2]', 'price[+2]']
# ['dvd[+2]', 'sound[+2]']
# ['read[+2]', ' svcd[+2]', ' vbr mp3 cd[+2]']
# ['disc[-1]', ' recognize[-2]']
# ['use[+2]', ' size[+2]', 'look[+2]']
# ['player[-3][u]', 'customer service[-3]']
# ['design[+2]', 'player[+2]']
# ['read[-2]', ' dvd[-2]']
# ['run[+2]', ' dvd[+2]']
# ['sound[+3]', 'picture clarity[+3]']
# ['case[+2]', 'price[+2][u]']
# ['size[+1]', 'machine[+2]']
# ['picture[+2]', 'sound[+2]']
# ['read[-2]', ' disc[-2]']
# ['set up[+1]', 'player[-2]']
# ['feature[+2]', 'reliability[-2]']
# ['unit[+3]', ' format[+2]']
# ['play[-2]', ' dvd[-2]']
# ['look[+2]', 'feature[+2]']
# ['player[-3][p]', ' motor[-2]', ' disc[-2]']
# ['ad-1600[-3]', ' ad-1220[-2]']
# ['size[+2]', 'weight[+2]']
# ['player[-2]', ' no disc[-2]']
# ['freeze[-2]', ' player[-2]']
# ['dvd[-3]', 'cd[-3]', ' no disc[-2]']
# ['size[+1]', 'remote layout[+1]']
# ['noise[-1]', ' external display[-2]']
# ['look[+2]', 'feature[+2]']
# ['dvd[-3]', ' read[-2]']
# ['dvd disc[-3]', ' read[-3]']
# ['read[+2]', ' cd audio disc[+2]']
# ['jpeg[-2]', 'dvd[-2]']
# ['play[+2]', ' cd[+2]', ' mp3[+2]', ' jpeg[+2]']
# ['play[-2]', ' windows media[-2]', ' divx rip[-2]']
# ['read[-2]', ' dvd[-2]', ' vcd[-2]']
# ['play[+2]', ' dvd-r[+2]']
# ['build quality[+2]', 'picture[+2]', 'sound[+2]']
# ['look[+3][u]', ' player[+1][p]']
# ['sound[+1]', 'weight[+1]']
# ['work[+3]', ' player[+2][u]']
# ['play[+2]', ' dvd[+2]']
# ['camera[+2]', ' use[+2]', ' feature[+1]']
# ['picture quality[+3]', ' use[+1]', ' option[+1]']
# ['speed[+2]', 'picture quality[+2]', 'function[+2]']
# ['exposure control[+2]', 'auto setting[+2]']
# ['size[-2][u]', 'weight[-2][u]']
# ['feature[+2]', ' ']
# ['optical zoom[+2]', 'digital zoom[+1]']
# ['lens cap[-1]', 'viewfinder[-1]']
# ['menu[+1]', 'button[+1]']
# ['zoom[+2]', 'lense[+2]']
# ['picture[+3]', ' control[+2]', ' battery[+2]', ' software[+2]']
# ['photo quality[+2]', ' auto mode[+2]']
# ['control[+2]', 'auto mode[+2]']
# ['feel[+2]', 'weight[+2]']
# ['picture[+2]', ' auto mode[+2]']
# ['color[+2]', 'picture[+2]', 'white balance[+2]']
# ['flash photo[-3]', 'noise[-2]']
# ['lag time[-2]', 'flash[-2]']
# ['g3[+3]', 'software[-2]']
# ['manual function[+2]', 'picture quality[+3]']
# ['viewfinder[-1]', 'lcd[+2]', 'camera[+3]']
# ['automode[+2]', 'manual mode[+2]']
# ['photo[+3]', ' use[+3]', ' software[+2]']
# ['focus[-2]', ' shoot[-2]']
# ['control[+2]', 'menu[+2]']
# ['optical zoom[+3]', 'viewfinder[+1]']
# ['design[+2]', ' feature[+2]', 'use[+1][u]', 'battery[+2]']
# ['use[+1][u]', 'design[+1][u]']
# ['use[+3]', 'control[+2]']
# ['option[+1}', ' control[+1]']
# ['macro[+2]', ' auto mode[+2]']
# ['picture[+3]', 'learning curve[+1]']
# ['picture[+2]', 'feel[+1][u]']
# ['lens[+2]', 'optical zoom[+1]']
# ['camera[+3]', 'use[+1]', 'photo[+3]']
# ['quality[+2]', 'lens[+2]']
# ['weight[-1]', 'camera[+2]']
# ['size[+2]', 'weight[+2]', 'navigational system[+2]', ' sound[+3]']
# ['battery[+2]', 'leather case[+2]']
# ['battery life[+2]', 'price[+2]']
# ['sound[+3]', ' headphone[-2]']
# ['battery[+2]', 'construction[+2]', 'size[+2]', 'weight[+2]']
# ['size[+1][u]', 'sound[+2]', 'price[+2]']
# ['player[+]', ' price[+3]']
# ['player[+3]', 'use[+3]', ' software[+2]', 'sound[+3]']
# ['setup[-3]', 'interface[-3]']
# ['earphone[-1]', 'software[-1]']
# ['screen[+2]', 'switch[-2]']
# ['headphone[-1]', ' sound[+3]']
# ['deal[+3]', ' mp3 player[+3]']
# ['player[+3][p]', 'look[+2][u]']
# ['sound[+3]', 'earphone[-3]']
# ['size[-2][u]', 'weight[-2][u]', 'look[-1]', 'folder structure[-1]']
# ['interface[+3][p]', 'software[+3][p]']
# ['sound quality[+2]', 'look[+3]', 'screen[+2]', ' battery[+3]']
# ['size[+1][u]', 'weight[+1]']
# ['product[+2][u]', 'price[+3]']
# ['setup[2]', ' transfer[+2]']
# ['use[+3]', ' playback quality[+3]', 'price[+2]']
# ['size[-1]', 'weight[-1]']
# ['price[+2]', 'battery[+2]']
# ['price[+3]', 'feature[+3]']
# ['battery life[+2]', 'online music service[+2]', 'pc compatibility[+2]']
# ['sound[+2]', 'battery life[+2]', 'price[+2][u]']
# ['style[+1]', 'size[+1][u]', 'control[+1]']
# ['player[+2][p]', 'button[+2]']
# ['player[+3]', 'software[-2]']
# ['look[+3]', 'size[+2][u]', 'weight[+2][u]']
# ['sound quality[+3]', 'size[+2]', 'price[+2]']
# ['sound[+2]', ' price[+2]', ' player[-1]']
# ['button[+3]', 'interface[+3]']
# ['click buttons[+3]', ' display[+2]']
# ['size[+1][u]', 'weight[+1][u]', 'look[+2]', 'display[+2]']
# ['player[+2]', 'sound[+3]']
# ['software[+3]', 'player[+3]']
# ['navigation[+2]', 'scroll[-2]']
# ['price[+2][u]', ' player[+2]']
# ['sound[+3]', 'size[-1][u]']
# ['weight[-1][u]', 'battery life[+1]']
# ['tag[-1]', 'software[-1]']
# ['control[-2]', 'look[-2]']
# ['screen[+3]', 'equilizer[+2]']
# ['size[-1][u]', 'weight[+1]', 'software[-1]']
# ['price[+2]', 'sound[+2]']
# ['weight[-2][u]', 'size[-2][u]']
# ['price[+2]', 'capacity[+2]']
# ['design[+2]', 'interface[+1]']
# ['player[+2]', 'software[-2]', ' rip[-2]', ' transfer[-2]']
# ['battery[+2]', 'sound[+3]']
# ['software[-2]', 'case[-2]']
# ['rip[+2]', ' quality[+2]']
# ['playlist[+1]', 'cd rip[+1]']
# ['sound[+2]', 'volume[+2]']
# ['player[-3]', 'software[-2]']
# ['player[+2]', 'sound quality[+2]']
# ['navigation[+2]', 'sync[+2]']
# ['sound[+2]', 'power output[+2]']
# ['user interface[+2]', 'navigation[+2]']
# ['look[+2]', 'build[+2]']
# ['fm[-1]', 'voice recording[-1]']
# ['sound[+2]', 'interface[+2]', 'battery[+2]', 'software[+2]', ' wake up[+2]', 'play mode[+2]']
# ['plug and play[-2]', 'id3[-2]', 'fm[-1]', 'recording[-1]']
# ['size[-2][u]', 'weight[-2][u]', 'wheel[-3]']
# ['product[+3]', ' sound[+3]', ' use[+2]']
# ['menue[-3]', 'control[-3]']
# ['storage[+3]', 'navigation[+2]', 'playlist[+2]', 'battery[+2]']
# ['battery life[-2]', 'manual[-2]', 'lock up[-2]', 'replacement battery[-2]']
# ['construction[-2]', 'support[-2]', 'scroll wheel[-2]', 'headphone jack[-2]']
# ['sound quality[+2]', 'battery life[+2]', 'price[+2]']
# ['size[+1]', 'value[+1]', 'design[+1]', 'software[-2]']
# ['sound[+2]', 'earbud[-2]']
# ['value[+2]', 'use[+2]']
# ['sound quality[+2]', 'volume[+2]']
# ['sound[+2]', 'battery life[+3]', 'battery[+2]', 'storage[+1]', 'screen[+2]', ' firmware[+1]', 'price[+2]']
# ['warranty[-2]', 'freeze up[-1]', 'navigation wheel[-2]']
# ['size[+3]', 'design[+3]']
# ['sound[+3]', 'battery life[-1]']
# ['control[-2]', 'software[-2]']
# ['picture[+3]', ' macro[+3]']
# ['auto focus[+2]', 'scene mode[+2]']
# ['camera[+2][p]', ' use[+1][u]', ' feature[+2]']
# ['auto mode[+1]', 'scene mode[+2]']
# ['macro mode[+3]', 'picture[+3]']
# ['camera[+3]', ' use[+1]']
# ['camera[+2]', ' picture[+2]', ' close-up shooting[+3]']
# ['camera[+2]', 'customer service[-2]']
# ['picture[+3]', 'delay[+1]']
# ['auto mode[+2]', ' manual mode[+2]', ' scene mode[+2]']
# ['digital zoom[+2]', 'optical zoom[+2]']
# ['touchup[+2]', ' redeye[+2]']
# ['use[+1][u]', 'quality[+2]', 'size[+1]']
# ['picture[+2]', 'ease of use[+2]']
# ['picture[+2]', 'print[+2]']
# ['4mp[+2]', 'optical zoom[+2]']
# ['software[+3]', ' online service[+2]']
# ['camera[+3]', ' feature[+2]']
# ['picture quality[+2]', 'function[+2]']
# ['camera[+3]', 'picture[+2]']
# ['picture[+2]', 'indoor shot[+1]']
# ['autofocus[+1]', 'scene mode[+1]', 'manual mode[+1]']
# ['use[+1]', ' accessory[+2]']
# ['picture quality[+3]', 'feature[+3]']
# ['design[+2]', 'construction[+2]', 'optic[+2]']
# ['picture quality[+3]', 'movie[+1]']
# ['use[+1]', 'feature[+2]', ' camera[+2]']
# ['weight[+2]', ' picture[+2][u]']
# ['photo quality[+3]', 'print[+2]']
# ['size[+2][u]', 'control[+2]']
# ['price[+2][u]', 'learn[+2]', 'image[+3]']
# ['auto mode[+2]', 'scene mode[+2]', 'manual mode[+2]']
# ['camera[+3]', ' print quality[+3]']
# ['closeup mode[+2]', ' battery[+2]']
# ['phone[+3]', ' work[+2]']
# ['speaker phone[+2]', 'radio[+2]', 'infrared[+2]']
# ['sprint plan[-2]', 'sprint customer service[-3]']
# ['size[+1][u]', ' sturdy[+2]']
# ['game[+2]', 'pim[+2]', 'radio[+2]']
# ['sound volume[+1]', ' ear[-2]']
# ['ringtone[+1]', 'background[+1]', 'screensaver[+1]', 'memory[-2]']
# ['battery life[+2]', 'size[+2]', 'volume[-1][u]']
# ['radio[+2]', ' radio[-1]']
# ['phone[+2]', 'warranty[-2]']
# ['sound quality[+2]', ' fm[+1]', ' earpiece[+1]']
# ['size[-2][u]', ' operate[-2][u]', ' button[-2]']
# ['speakerphone[+3]', ' reception[+2]']
# ['speakerphone[+3]', 'radio[+3]']
# ['size[+2]', 'weight[+2]']
# ['bluetooth[-1]', 'high speed internet[-1]']
# ['ringing tone[+3]', 'radio[+2]']
# ['phone[+2]', 'size[+2]']
# ['reception[+3]', 'sound quality[+3]']
# ['size[+2]', 'weight[+2]']
# ['voice dialing[-1]', 'headset jack[-1]']
# ['weight[+1]', ' design[+1]']
# ['picture[-1]', ' ringtone[-1]']
# ['quality[+3]', 'durability[+3]']
# ['screen[+1]', ' ring tone[+1]']
# ['weight[+1]', 'phone[+2]']
# ['phone[+2]', ' menu[+2]']
# ['wallpaper[+1]', 'tune[+2]']
# ['battery life[+2][u]', 'reception[+2]', ' application[+2]']
# ['size[+1][u]', 'game[+1]', 'ringtone[+1]']
# ['phone[+2]', 'gsm[-1]']
# ['phone[+2]', 'screen[+2]', 'ergonomics[+2]', 'size[+1][u]']
# ['size[+1][u]', 'weight[+1]', 'design[+3]']
# ['color screen[+1]', 'ringtone[+1]']
# ['sound[-2]', 'volume[-2]']
# ['phone[+2]', ' feature[+2]']
# ['weight[+2][u]', 'battery life[+2]']
# ['tone[+1]', 'wallpaper[+1]', 'application[+1]']
# ['message[+1]', 'picture sharing[+1]']
# ['size[+2]', 'feature[+2]']
# ['phone book[+2]', 'speakerphone[+2]']
# ['battery life[+2]', 'radio[+2]', 'signal[+2]', 'speakerphone[+2]', 'application[+1]']
# ['size[+1]', 'speakerphone[+1]', 'plan[+1]']
# ['phone[+3]', ' look[+2]']
# ['phone[+2]', 'use[+1]', 'network[+2]']
# ['service[+1]', 'ringtone[+2]']
# ['size[+2][u]', ' look{+1]']
# ['screen[+2]', 'sound[+2]']
# ['voice quality[+3]', 'reception[+2]']
# ['screen[+2]', 'command[+2]']
# ['resolution[+2]', ' color[+2]']
# ['gprs[-1]', 't-zone[+2]']
# ['menu[+2]', ' feature[+2]']
# ['phone[+2]', ' feature[+2]']
# ['design[+2]', 'screen[+2]']
# ['weight[+2]', 'signal[+2]']

# %% [markdown]
# ## Prepare training data for input to neural network

# %%
max_len = max([len(x.question.split()) for x in trec_train])
questions_train = [x.question for x in trec_train]
labels_train = [x.label for x in trec_train]

# Convert words to indexes
tokenizer = Tokenizer()
tokenizer.fit_on_texts(questions_train)
sequences_train = tokenizer.texts_to_sequences(questions_train)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

# Pad the sequences to the 'max_len'
data_train = pad_sequences(sequences_train, maxlen=max_len)

# Encode the labels, each must be a vector with dim = num. of possible labels
le = LabelEncoder()
le.fit(labels_train)
labels_encoded_train = le.transform(labels_train)
categorical_labels_train = to_categorical(labels_encoded_train, num_classes=None)
print('Shape of train data tensor:', data_train.shape)
print('Shape of train label tensor:', categorical_labels_train.shape)

# Shuffle training data
indices = np.arange(data_train.shape[0])
np.random.shuffle(indices)
x_train = data_train[indices]
y_train = categorical_labels_train[indices]
# Out:
# Found 8461 unique tokens.
# Shape of train data tensor: (5381, 37)
# Shape of train label tensor: (5381, 6)

# %%
# Pre-Process test data
questions_test = [x.question for x in trec_test]
y_test = [x.label for x in trec_test]
sequences_test = tokenizer.texts_to_sequences(questions_test)
x_test = pad_sequences(sequences_test, maxlen=max_len)

print('Shape of test data tensor:', x_test.shape)
# Out:
# Shape of test data tensor: (500, 37)

# %% [markdown]
# # Utils functions

# %%
def compute_metrics(raw_predictions, label_encoder):
    # convert raw predictions to class indexes
    threshold = 0.5
    class_predictions = [(x > threshold).astype(int) for x in model.predict(x_test)]
    
    # convert raw predictions to class indexes
    threshold = 0.5
    class_predictions = [(x > threshold).astype(int) for x in model.predict(x_test)]

    # select only one class (i.e., the dim in the vector with 1.0 all other are at 0.0)
    class_index = ([np.argmax(x) for x in class_predictions])

    # convert back to original class names
    pred_classes = label_encoder.inverse_transform(class_index)

    # print precision, recall, f1-score report
    print(classification_report(y_test, pred_classes))
    
def load_embeddings():
    glove_dir = '/Users/dsbatista/resources/glove.6B'

    embeddings_index = {}
    f = open(os.path.join(glove_dir, 'glove.6B.100d.txt'))
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()

    print('Found %s word vectors.' % len(embeddings_index))
    
    return embeddings_index


def create_embeddings_matrix(embeddings_index, vocab_size, embedding_dim=100):    
    embeddings_matrix = np.random.rand(vocab_size, embedding_dim)
    for i, word in enumerate(embeddings_index):
        if i < vocab_size:
            embedding_vector = embeddings_index.get(word)            
            if embedding_vector is not None:
                embeddings_matrix[i] = embedding_vector
    print('Matrix shape: {}'.format(embeddings_matrix.shape))
    return embeddings_matrix


def get_embeddings_layer(embeddings_matrix, name, max_len, trainable=False):
    embedding_layer = Embedding(
        input_dim=embedding_matrix.shape[0],
        output_dim=embedding_matrix.shape[1], 
        input_length=max_len, 
        weights=[embeddings_matrix], 
        trainable=trainable, 
        name=name)
    
    return embedding_layer


def get_conv_pool(sufix, n_grams=[3,4,5], feature_maps=100):
    # rectified linear units, filter windows (h) of 3, 4, 5 with 100 feature maps each
    branches = []
    for n in n_grams:
        branch = Conv1D(filters=feature_maps, kernel_size=n, name='Conv_'+sufix+'_'+str(n))(x)
        branch = MaxPooling1D(pool_size=2, strides=None, padding='valid', name='MaxPooling_'+sufix+'_'+str(n))(branch)
        branch = Flatten(name='Flatten_'+sufix+'_'+str(n))(branch)
        branches.append(branch)
        
    return branches

# %% [markdown]
# ## Convolutional Neural Networks for Sentence Classification
# https://arxiv.org/pdf/1408.5882.pdf

# %% [markdown]
# ## 3.1 Hyperparameters and Training

# %% [markdown]
# For all datasets we use:
#
# - rectified linear units;
# - filterwindows (h) of 3, 4, 5 with 100 feature maps each;
# - dropout rate (p) of 0.5;
# - l2 constraint (s) of 3;
# - mini-batch size of 50;
#
# These values were chosen via a grid search on the SST-2 dev set.
#
# We do not otherwise perform any dataset specific tuning other than early stopping on dev sets. For datasets without a standard dev set we randomly select 10% of the training data as the dev set.
#
# Training is done through stochastic gradient descent over shuffled mini-batches with the Adadelta update rule (Zeiler, 2012).

# %% [markdown]
# ## 3.2 Pre-trained Word Vectors

# %% [markdown]
# We use the publicly available:
#
# - word2vec vectors that were trained on 100 billion words from Google News.
# - Words not present in the set of pre-trained words are initialized randomly.

# %% [markdown]
# ## 3.3 Models Variations

# %% [markdown]
# ## 1) `CNN-rand`: all words are randomly initialized and then modified during training

# %%
from keras.layers import concatenate

embedding_dim=100
vocab_size=1000
max_len=37

# create the embedding layer
embedding_matrix = np.random.rand(vocab_size, embedding_dim)
embedding_layer = get_embeddings_layer(embedding_matrix, 'embedding_layer_dynamic', max_len, trainable=True)

# connect the input with the embedding layer
i = Input(shape=(max_len,), dtype='int32', name='main_input')
x = embedding_layer(i)

# generate several branches in the network, each for a different convolution+pooling operation, 
# and concatenate the result of each branch into a single vector
branches = get_conv_pool('dynamic')
z = concatenate(branches, axis=-1)

# pass the concatenated vector to the predition layer
o = Dense(1, activation='sigmoid', name='output')(z)

model_1 = Model(inputs=i, outputs=o)
model_1.compile(loss={'output': 'binary_crossentropy'}, optimizer='adam')

# %%
SVG(model_to_dot(model_1, show_layer_names=True, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# ## 2) CNN-static: pre-trained vectors with all the words— including the unknown ones that are randomly initialized—kept static and only the other parameters of the model are learned

# %%
embeddings_index = load_embeddings()
# Out:
# Found 400000 word vectors.

# %%
embeddings_matrix = create_embeddings_matrix(embeddings_index, 1000, 100)
# Out:
# Matrix shape: (1000, 100)

# %%
embedding_layer = get_embeddings_layer(embedding_matrix, 'embedding_layer_static', max_len, trainable=False)

# connect the input with the embedding layer
i = Input(shape=(max_len,), dtype='int32', name='main_input')
x = embedding_layer(i)

# generate several branches in the network, each for a different convolution+pooling operation, 
# and concatenate the result of each branch into a single vector
branches = get_conv_pool('static')
z = concatenate(branches, axis=-1)

# pass the concatenated vector to the predition layer
o = Dense(1, activation='sigmoid', name='output')(z)

model_2 = Model(inputs=i, outputs=o)
model_2.compile(loss={'output': 'binary_crossentropy'}, optimizer='adam')

# %%
SVG(model_to_dot(model_2, show_layer_names=True, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# ## 3) Same as above but word vectors are fine-tuned

# %%
embedding_layer = get_embeddings_layer(embedding_matrix, 'embedding_layer_dynamic', max_len, trainable=True)

# connect the input with the embedding layer
i = Input(shape=(max_len,), dtype='int32', name='main_input')
x = embedding_layer(i)

# generate several branches in the network, each for a different convolution+pooling operation, 
# and concatenate the result of each branch into a single vector
branches = get_conv_pool('static')
z = concatenate(branches, axis=-1)

# pass the concatenated vector to the predition layer
o = Dense(1, activation='sigmoid', name='output')(z)

model_3 = Model(inputs=i, outputs=o)
model_3.compile(loss={'output': 'binary_crossentropy'}, optimizer='adam')

# %%
SVG(model_to_dot(model_3, show_layer_names=True, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# ## 4) CNN-multichannel: A model with two sets of word vectors. Each set of vectors is treated as a `channel` and each filter is applied

# %% [markdown]
# ### dynamic channel

# %%
embedding_layer_dynamic = get_embeddings_layer(embedding_matrix, 'embedding_layer_dynamic', max_len, trainable=True)

# connect the input with the embedding layer
input_dynamic = Input(shape=(max_len,), dtype='int32', name='input_dynamic')
x = embedding_layer_dynamic(input_dynamic)

# generate several branches in the network, each for a different convolution+pooling operation, 
# and concatenate the result of each branch into a single vector
branches_dynamic = get_conv_pool('static')
z_dynamic = concatenate(branches_dynamic, axis=-1)

# %% [markdown]
# ### static channel

# %%
embedding_layer_static = get_embeddings_layer(embedding_matrix, 'embedding_layer_static', max_len, trainable=False)

# connect the input with the embedding layer
input_static = Input(shape=(max_len,), dtype='int32', name='input_static')
x = embedding_layer_static(input_static)

# generate several branches in the network, each for a different convolution+pooling operation, 
# and concatenate the result of each branch into a single vector
branches_static = get_conv_pool('dynamic')
z_static = concatenate(branches_static, axis=-1)

# %%
z = concatenate([z_static,z_dynamic], axis=-1)

# pass the concatenated vector to the predition layer
o = Dense(6, activation='sigmoid', name='output')(z)

model_4 = Model(inputs=[input_static, input_dynamic], outputs=o)
model_4.compile(loss={'output': 'binary_crossentropy'}, optimizer='adam')

# %%
SVG(model_to_dot(model_4, show_layer_names=True, show_shapes=True).create(prog='dot', format='svg'))
